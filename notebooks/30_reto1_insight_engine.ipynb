# %% [markdown]
# # 30 — Reto 1: Insight Engine
#
# **Estado:** placeholder — pendiente.
#
# **Prerrequisito:** `20_reto1_semantic_layer.ipynb` completado (contratos de métricas definidos).
#
# **Objetivo de esta fase:**
# - Implementar los 4 detectores transparentes como funciones de producción:
#   - WoW delta con thresholds por métrica.
#   - Decline streak con umbral mínimo configurable.
#   - Desviación vs. peer median con filtro de peer_size mínimo.
#   - Robust z-score (MAD) con manejo de MAD=0.
# - Definir reglas de priorización de alertas (qué detector + métrica activa alerta alta/media/baja).
# - Validar detectores sobre datos históricos disponibles (falsos positivos, cobertura).
# - Diseñar formato de output de alerta: qué se muestra, qué se omite, cómo se explica.
