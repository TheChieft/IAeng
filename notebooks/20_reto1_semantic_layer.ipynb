# %% [markdown]
# # 20 — Reto 1: Semantic Layer
#
# **Estado:** placeholder — pendiente.
#
# **Prerrequisito:** `00_data_prep_common.ipynb` completado (artefactos en `data/processed/`).
#
# **Objetivo de esta fase:**
# - Definir contrato de métricas: nombre canónico, unidad, orientación deseable (alto/bajo mejor).
# - Definir dimensiones válidas de agregación y sus combinaciones permitidas.
# - Definir ventanas temporales y reglas de cobertura mínima.
# - Implementar funciones determinísticas reutilizables: `top_n_by_metric`, `trend_by_zone`, `compare_segments`, etc.
# - Versionar el contrato como base para el bot y el insight engine.
#
# **Por qué antes del bot:**
# El bot no debe resolver semántica en tiempo de inferencia. Debe llamar funciones con contratos fijos. Esta capa define esos contratos.
