# %% [markdown]
# # 40 — Reto 1: Chatbot Design
#
# **Estado:** placeholder — pendiente.
#
# **Prerrequisito:** `30_reto1_insight_engine.ipynb` completado.
#
# **Objetivo de esta fase:**
# - Diseñar la arquitectura del bot: cómo mapea preguntas en lenguaje natural a funciones determinísticas de la capa semántica.
# - Definir los tipos de pregunta que el bot puede responder (ranking, tendencia, comparación, hipótesis).
# - Diseñar el formato de respuesta: qué incluye, qué omite, cómo cita la fuente.
# - Manejar preguntas fuera de alcance: qué responde el bot cuando no tiene datos suficientes.
# - Prototipo de interfaz conversacional sobre la capa semántica.
#
# **Principio clave:**
# El LLM interpreta la intención y genera el plan. Las funciones determinísticas ejecutan el cálculo. El LLM genera la narrativa a partir del resultado estructurado — no del dato crudo.
